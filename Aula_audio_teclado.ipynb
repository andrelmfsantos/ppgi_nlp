# %% [markdown]
# # Título 1

# %%
pip install librosa

# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt
import scipy

# %%
file_path = "/content/audio_teclado.wav"
(samples, sampling_rate) = librosa.load(file_path, sr = None, mono = True, offset = 0.0, duration = None)
len(samples), sampling_rate
# Out:
# (647104, 48000)

# %%
tempo_audio = librosa.get_duration(filename=file_path)
tempo_audio
# Out:
# <ipython-input-21-ded469eb66c5>:1: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   tempo_audio = librosa.get_duration(filename=file_path)
# 13.481333333333334

# %%
plt.figure()
librosa.display.waveshow(y = samples, sr = sampling_rate)
plt.xlabel(" Tempo em segundos -->")
plt.ylabel("Amplitude")
plt.show()

# %%
print(len(samples))
sampling_rate*tempo_audio
# Out:
# 647104
# 647104.0
